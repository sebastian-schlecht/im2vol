# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

data = np.load("./data/resunet_connected_mse_epoch_42_loss_train.npy")

plt.plot(data)
plt.show()

# %%
import h5py as h
import numpy as np
import matplotlib.pyplot as plt

f = h.File("/data/data/test_v2.hdf5")
images = np.array(f["images"])
print images.shape
depths = np.array(f["depths"])
# Out:
# (654, 3, 240, 320)

# %%
# %matplotlib inline

idx = 99

plt.imshow(images[idx].transpose((1,2,0)))
plt.show()
plt.imshow(depths[idx])
plt.show()

print depths[idx].mean()
# Out:
# 2.40636

# %%
f = h.File("/data/data/nyu_v2.hdf5")
images = f["images"][0:5000]
depths = f["depths"][0:5000]

# %%
s = images.std()

# %%
# %matplotlib inline

idx = 13
plt.imshow(images[idx].transpose((1,2,0)))
plt.show()
cpy = depths[idx].copy()
cpy[cpy > 2] = 0
plt.imshow(cpy)
plt.show()

print depths[idx].mean()
