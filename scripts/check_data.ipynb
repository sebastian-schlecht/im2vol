# %%
# %matplotlib inline
import h5py
import numpy as np
import matplotlib.pyplot as plt


_file = "/home/ga29mix/data/nyu_v2.hdf5"

f = h5py.File(_file)

images = np.array(f["images"][0:100])
depths = np.array(f["depths"][0:100])

idx = 0 
plt.imshow(images[idx].transpose((1,2,0)))
plt.show()
plt.imshow(depths[idx])
plt.show()
