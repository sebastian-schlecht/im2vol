# %%
# !ls
# Out:
# cifar-10-batches-py		 t10k-images-idx3-ubyte.gz
# cifar10_deep_residual_model.npz  t10k-labels-idx1-ubyte.gz
# cifar-10-python.tar.gz		 train-images-idx3-ubyte.gz
# maxdistloss.ipynb		 train-labels-idx1-ubyte.gz
# plot.ipynb			 wide_resnet_4_1_00_log.pkl
# residual_maxdist.ipynb		 wide_resnet_4_1_01_100_log.pkl
# residual_terminal.py		 wide_resnet_4_1_01_1_log.pkl

# %%
# %matplotlib inline
import cPickle as pickle
import numpy as np
import matplotlib.pyplot as plt


COLORS = ['r', 'b', 'g']

data = [
    'wide_resnet_4_1_00_log.pkl', 
    'wide_resnet_4_1_01_1_log.pkl',
    'wide_resnet_4_1_01_100_log.pkl'
]

def load_data(f,key, n):
    data = pickle.load( open( f, "rb" ) )
    if n ==0:
        val_e = data[key][0:]
    else:        
        val_e = data[key][0:n]
    return val_e

def plot_all(key, n=0):
    idx = 0
    for _file in data:
        d = load_data(_file, key, n)
        x = np.arange(len(d))
        plt.plot(x, d, COLORS[idx])
        idx += 1
    plt.show()

plot_all('val_error')
plot_all('val_acc')
